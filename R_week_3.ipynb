# %% [markdown]
# Adition with data vectors

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %% [markdown]
# R is a calculator

# %%
2^3
# Out:
# [1] 8

# %%
2**3
# Out:
# [1] 8

# %%
2^0.5
# Out:
# [1] 1.414214

# %%
2**0.5
# Out:
# [1] 1.414214

# %%
2^-0.5
# Out:
# [1] 0.7071068

# %% [markdown]
# Power operation with scalar

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %% [markdown]
# Power operation with vector

# %%
c(2,3,5,7)^c(2,3)
# Out:
# [1]   4  27  25 343

# %% [markdown]
# Power operation with vector

# %%
c(1,2,3,4,5,6)^c(2,3,4)
# Out:
# [1]    1    8   81   16  125 1296

# %% [markdown]
# Power operation with vector

# %%
c(2,3,5,7)^c(2,3,4)
# Out:
# Warning message in c(2, 3, 5, 7)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 625  49

# %% [markdown]
# Integer division with scalar

# %%
c(2,3,5,7) %/% 2
# Out:
# [1] 1 1 2 3

# %% [markdown]
# Integer division with data vector

# %%
c(2,3,5,7) %/% c(2,3)
# Out:
# [1] 1 1 2 2

# %% [markdown]
# Interger division with data vector

# %%
c(2,3,5) %/% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# Modulo Division (x mod y) with scalars

# %%
c(2,3,5,7) %% 2
# Out:
# [1] 0 1 1 1

# %% [markdown]
# Modulo Division (x mod y) with data vectors

# %%
c(2,3,5,7) %% c(2,3)
# Out:
# [1] 0 0 1 1

# %% [markdown]
# Modulo Division (x mod y) with data vectors

# %%
c(2,3,5) %/% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# Maximun

# %%
max(1.2, 3.4, -7.8)
# Out:
# [1] 3.4

# %%
max(c(1.2, 3.4, -7.8))
# Out:
# [1] 3.4

# %% [markdown]
# Minimum

# %%
min(1.2, 3.4, -7.8)
# Out:
# [1] -7.8

# %%
min(c(1.2, 3.4, -7.8))
# Out:
# [1] -7.8

# %% [markdown]
# Arithmetic Mean

# %%
mean(2,3,4)
# Out:
# [1] 2

# %%
mean(c(2,3,4))
# Out:
# [1] 3

# %% [markdown]
# abs for finding the absolute values

# %%
abs(-4)
# Out:
# [1] 4

# %%
abs(c(-1,-2,-3,4,5))
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# sqrt for finding the square root of values

# %%
sqrt(4)
# Out:
# [1] 2

# %%
sqrt(c(4,9,16,25))
# Out:
# [1] 2 3 4 5

# %% [markdown]
# rounds for finding the round of values

# %%
round(1.23)
# Out:
# [1] 1

# %%
round(1.83)
# Out:
# [1] 2

# %% [markdown]
# log for finding the natural log(ln) of values

# %%
log(10)
# Out:
# [1] 2.302585

# %%
log(exp(1))
# Out:
# [1] 1

# %%
log(c(10,100,1000))

# %% [markdown]
# log10 for finding the log (with base 10) of value

# %%
log10(10)
# Out:
# [1] 1

# %%
log10(100)
# Out:
# [1] 2

# %%
log10(c(10,100,1000))
# Out:
# [1] 1 2 3

# %% [markdown]
# An assignment can also be used to save

# %%
x1 = c(1,2,3,4)
x1
# Out:
# [1] 1 2 3 4

# %%
x2 = x1^2
x2
# Out:
# [1]  1  4  9 16

# %% [markdown]
# Assignment calculation with scalar ,data vector and built in function also work

# %%
c(1,2,3,4) + sum(c(1,2,3,4)) * prod(c(1,2))
# Out:
# [1] 21 22 23 24

# %%
abs( c(1,2,3,4) - sum(c(1,2,3,4))*prod(c(1,2)) )
# Out:
# [1] 19 18 17 16

# %% [markdown]
# Entering data row wise in a matrix

# %%
y = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = TRUE)

y
# Out:
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8))
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = FALSE)
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8) )

x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# Properties of a Matrix

# %%
dim(x) # tells the dimension of matrix
# Out:
# [1] 4 2

# %%
nrow(x) # tells the number of rows
# Out:
# [1] 4

# %%
ncol(x) # tells the number of columns
# Out:
# [1] 2

# %%
mode(x)
# Out:
# [1] "numeric"

# %%
attributes(x) #Informs the dimension of matrix
# Out:
# $dim
# [1] 4 2

# %%
help("matrix")
